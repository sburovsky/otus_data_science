# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# ### Решение

# %% [markdown]
# a)
# $$ AB = \begin{pmatrix}
#   7*(-9) & 7*(-6)+1*(-5)+(-1)*5 & 7*2+1*5+(-1)*(-7)\\
#   1*(-9) & 1*(-6)+(-3)*(-5)+5*5 & 1*2+(-3)*5+5*(-7)\\
#   (-6)*(-9) & (-6)*(-6)+2*(-5)+(-2)*5 & (-6)*2+2*5+(-2)*(-7)
#  \end{pmatrix} =
# \begin{pmatrix}
#   -63 & -52 & 26\\
#   -9 & 34 & -48\\
#   54 & 16 & 12
#  \end{pmatrix}
#  $$

# %% [markdown]
# б)
# $$ AB = \begin{pmatrix}
#   (-9)*1+5*7+2*(-2) & (-9)*(-5)+5*3+2*4 & (-9)*1+5*1+2*7\\
#   (-8)*1+(-3)*7+4*(-2) & (-8)*(-5)+(-3)*3+4*4 & (-8)*1+(-3)*1+4*7\\
#   (-5)*1+8*7+(-8)*(-2) & (-5)*(-5)+8*3+(-8)*4 & (-5)*1+8*1+(-8)*7
#  \end{pmatrix} =
# \begin{pmatrix}
#   22 & 68 & 10\\
#   -37 & 47 & 17\\
#   67 & 17 & -53
#  \end{pmatrix}
#  $$

# %% [markdown]
# в)
# $$ AB = \begin{pmatrix}
#  (-4)*9 \\
#  (-2)*2+2*9\\
#   4*2+6*9
#  \end{pmatrix} =
# \begin{pmatrix}
#  -36\\
#   14\\
#   62
#  \end{pmatrix}
#  $$

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# ### Решение

# %% [markdown]
# а)
# Вычтем из третьей строки первую и вторую строку:
# $$
# \begin{pmatrix}
#   4 & 2 & 3\\
#   5 & 2 & 1\\
#   0 & 0 & 0
#  \end{pmatrix} $$

# %% [markdown]
# Вычтем из второй строки первую и поменяем первую и вторую строки местами:
# $$
# \begin{pmatrix}
#   1 & 0 & -2\\
#   4 & 2 & 3\\
#   0 & 0 & 0
#  \end{pmatrix} $$

# %% [markdown]
# Вычтем из второй строки четыре первых строки:
# $$
# \begin{pmatrix}
#   1 & 0 & -2\\
#   0 & 2 & 11\\
#   0 & 0 & 0
#  \end{pmatrix} $$

# %% [markdown]
# #### Ответ:
# Ранг матрицы равен 2 (по количеству ненулевых строк)

# %% [markdown]
# б) Вычтем из второй строки две первых строки:
# $$
# \begin{pmatrix}
#   3 & 2 & 1 & 5\\
#   0 & 0 & 1 & -3\\
#   9 & 6 & 5 & 9\\
#   3 & 2 & 0 & 8
#  \end{pmatrix} $$

# %% [markdown]
# Вычтем из третьей строки три первых строки:
# $$
# \begin{pmatrix}
#   3 & 2 & 1 & 5\\
#   0 & 0 & 1 & -3\\
#   0 & 0 & 2 & -6\\
#   3 & 2 & 0 & 8
#  \end{pmatrix} $$

# %% [markdown]
# Вычтем из четвертой строки первую строку:
# $$
# \begin{pmatrix}
#   3 & 2 & 1 & 5\\
#   0 & 0 & 1 & -3\\
#   0 & 0 & 2 & -6\\
#   0 & 0 & -1 & 3
#  \end{pmatrix} $$

# %% [markdown]
# Прибавим к четвертой строке вторую строку:
# $$
# \begin{pmatrix}
#   3 & 2 & 1 & 5\\
#   0 & 0 & 1 & -3\\
#   0 & 0 & 2 & -6\\
#   0 & 0 & 0 & 0
#  \end{pmatrix} $$

# %% [markdown]
# Вычтем из третьей строки две вторых строки:
# $$
# \begin{pmatrix}
#   3 & 2 & 1 & 5\\
#   0 & 0 & 1 & -3\\
#   0 & 0 & 0 & 0\\
#   0 & 0 & 0 & 0
#  \end{pmatrix} $$

# %% [markdown]
# #### Ответ:
# Ранг матрицы равен 2 (по количеству ненулевых строк)

# %% [markdown]
# в) Вычтем из третьей строки первую и вторую строки:
# $$
# \begin{pmatrix}
#   1 & 2 & 1 & 1\\
#   0 & 1 & 1 & 1\\
#   0 & 0 & 0 & 0
#  \end{pmatrix} $$

# %% [markdown]
# #### Ответ:
# Ранг матрицы равен 2 (по количеству ненулевых строк)

# %% [markdown]
# ![3.png](attachment:3.png)

# %% [markdown]
# ### Решение

# %% [markdown]
# a)
# $$ det A = (-3)*1*(-3)+3*7*2+2*7*4-3*4*(-1)-2*7*(-3)-2*7*(-3) = -9+42+56+12+42+42 = 185 $$

# %% [markdown]
# б)
# $$ det B = (-1)*(-7)*2+0+2*(-10)*(-3)-2*(-7)*(-3)-(-1)*4*(-3)-0 = 14+60-42-12=20 $$

# %% [markdown]
# в)
# $$ det C = 0+(-2)*(-1)*(-7)+1*(-5)*2-0-4*(-1)*2-(-2)*(-5)*7 = -14-10+8-70 = -86 $$

# %% [markdown]
# г)
# Поскольку определитель матрицы не меняется при прибавлении к строке линейной комбинации других строк, прибавим к пятой строке вторую строку:
# $$
# \begin{pmatrix}
#   7 & -4 & -10 & 3 & 1\\
#   7 & -9 & 2 & -6 & -2\\
#   -3 & -8 & 3 & -7 & -7\\
#   7 & 8 & -4 & 2 & -8\\
#   7 & -4 & -10 & 3 & 1
#  \end{pmatrix} $$

# %% [markdown]
# Первая и пятая строки совпадают => матрица вырожденная =>
# $$ detD = 0 $$
